# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import os

COCOAUG_ROOT = "/home/scs_deal_projects_notapebackup/shared/DATASET/coco2014/thesis_outputs/coco_aug"
img_dir = Path(COCOAUG_ROOT) / "train_imgs"

fn = sorted(os.listdir(img_dir))[5]
img = Image.open(img_dir / fn).convert("RGB")

plt.imshow(img)
plt.title(f"Augmented: {fn}")
plt.axis("off")
plt.show()
